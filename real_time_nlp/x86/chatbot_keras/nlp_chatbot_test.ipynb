# %% [markdown]
# see: https://towardsdatascience.com/how-to-build-your-own-chatbot-using-deep-learning-bb41f970e281

# %%
# %%writefile requirements.txt
# tensorflow==2.3.1
# nltk==3.5
# colorama==0.4.3
# numpy==1.18.5
# scikit_learn==0.23.2
# Flask==1.1.2
# mlflow
# Out:
# Overwriting requirements.txt

# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow==2.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: nltk==3.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: colorama==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: numpy==1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (1.18.5)
# Requirement already satisfied: scikit_learn==0.23.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.23.2)
# Requirement already satisfied: Flask==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (1.1.2)
# Collecting mlflow
#   Downloading https://files.pythonhosted.org/packages/aa/2d/7fa1f6e310ded489d943ea20cd7977a9867cb8d81b526d9c9460ce4a5b39/mlflow-1.11.0-py3-none-any.whl (13.9MB)
#      |████████████████████████████████| 13.9MB 241kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.33.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (3.12.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.3.1->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nltk==3.5->-r requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from nltk==3.5->-r requirements.txt (line 2)) (4.41.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from nltk==3.5->-r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from nltk==3.5->-r requirements.txt (line 2)) (2019.12.20)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit_learn==0.23.2->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit_learn==0.23.2->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask==1.1.2->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask==1.1.2->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask==1.1.2->-r requirements.txt (line 6)) (2.11.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (1.3.0)
# Collecting querystring-parser
#   Downloading https://files.pythonhosted.org/packages/88/6b/572b2590fd55114118bf08bde63c0a421dcc82d593700f3e2ad89908a8a9/querystring_parser-1.2.4-py2.py3-none-any.whl
# Collecting sqlalchemy<=1.3.13
#   Downloading https://files.pythonhosted.org/packages/af/47/35edeb0f86c0b44934c05d961c893e223ef27e79e1f53b5e6f14820ff553/SQLAlchemy-1.3.13.tar.gz (6.0MB)
#      |████████████████████████████████| 6.0MB 39.0MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (2.8.1)
# Collecting azure-storage-blob>=12.0
#   Downloading https://files.pythonhosted.org/packages/b8/84/7e51b3e1156bcb89a20b9ec641d4fced4800aa79daac3a403898c32046be/azure_storage_blob-12.5.0-py2.py3-none-any.whl (326kB)
#      |████████████████████████████████| 327kB 32.3MB/s
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (3.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (1.1.3)
# Collecting docker>=4.0.0
#   Downloading https://files.pythonhosted.org/packages/9e/8c/8d42dbd83679483db207535f4fb02dc84325fa78b290f057694b057fcd21/docker-4.3.1-py2.py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 15.6MB/s
# Collecting databricks-cli>=0.8.7
#   Downloading https://files.pythonhosted.org/packages/20/d9/01d0bda8d764be9e7448a41c34eec002e67e88e0d558b80d0ba922b4f7f0/databricks-cli-0.13.0.tar.gz (54kB)
#      |████████████████████████████████| 61kB 7.5MB/s
# Collecting prometheus-flask-exporter
#   Downloading https://files.pythonhosted.org/packages/4c/d5/8a046d683c2cc084b6a502812827ede69b1064f95d93f94b83f809b21723/prometheus_flask_exporter-0.18.1.tar.gz
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (0.3)
# Collecting alembic<=1.4.1
#   Downloading https://files.pythonhosted.org/packages/e0/e9/359dbb77c35c419df0aedeb1d53e71e7e3f438ff64a8fdb048c907404de3/alembic-1.4.1.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 39.1MB/s
# Requirement already satisfied: requests>=2.17.3 in /usr/local/lib/python3.6/dist-packages (from mlflow->-r requirements.txt (line 7)) (2.23.0)
# Collecting gunicorn; platform_system != "Windows"
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 8.9MB/s
# Collecting gitpython>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/24/d1/a7f8fe3df258549b303415157328bfcc63e9b11d06a7ad7a3327f3d32606/GitPython-3.1.11-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 43.1MB/s
# Collecting gorilla
#   Downloading https://files.pythonhosted.org/packages/e3/56/5a683944cbfc77e429c6f03c636ca50504a785f60ffae91ddd7f5f7bb520/gorilla-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (50.3.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask==1.1.2->-r requirements.txt (line 6)) (1.1.1)
# Collecting cryptography>=2.1.4
#   Downloading https://files.pythonhosted.org/packages/4c/a2/6565c5271a79e3c96d7a079053b4d8408a740d4bf365f0f5f244a807bd09/cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 39.9MB/s
# Collecting msrest>=0.6.10
#   Downloading https://files.pythonhosted.org/packages/fa/f5/9e315fe8cb985b0ce052b34bcb767883dc739f46fadb62f05a7e6d6eedbe/msrest-0.6.19-py2.py3-none-any.whl (84kB)
#      |████████████████████████████████| 92kB 10.0MB/s
# Collecting azure-core<2.0.0,>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/4c/fa/46974f4a7ad78b27e3eda8a573cc0c2508849f0d7d360b61c07cc5b46014/azure_core-1.8.2-py2.py3-none-any.whl (122kB)
#      |████████████████████████████████| 122kB 44.9MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->mlflow->-r requirements.txt (line 7)) (2018.9)
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 42.5MB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from databricks-cli>=0.8.7->mlflow->-r requirements.txt (line 7)) (0.8.7)
# Requirement already satisfied: prometheus_client in /usr/local/lib/python3.6/dist-packages (from prometheus-flask-exporter->mlflow->-r requirements.txt (line 7)) (0.8.0)
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 9.2MB/s
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 7)) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 7)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 7)) (1.24.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.9MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0->mlflow->-r requirements.txt (line 7)) (1.14.3)
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-blob>=12.0->mlflow->-r requirements.txt (line 7)) (2.20)
# Building wheels for collected packages: sqlalchemy, databricks-cli, prometheus-flask-exporter, alembic
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.13-cp36-cp36m-linux_x86_64.whl size=1217166 sha256=cb3051de127e3ac26bccf0b7dddda5926a50828d6979302ed73432f46c8b6da3
#   Stored in directory: /root/.cache/pip/wheels/b3/35/98/4c9cb3fd63d21d5606b972dd70643769745adf60e622467b71
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.13.0-cp36-none-any.whl size=100347 sha256=240f93dc711fd0eb36c49cae9366e7717754948d6db4cf736b0fa972f81ed75d
#   Stored in directory: /root/.cache/pip/wheels/d3/ba/45/11e7abe40b8e21f4aab12a3051e269b24d17f2b288bb7418d5
#   Building wheel for prometheus-flask-exporter (setup.py) ... done
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.1-cp36-none-any.whl size=17157 sha256=4f03a10fa9b3ee249febc8d710b16c5f391847a0fa46f7bd46c5b8f266aa9f27
#   Stored in directory: /root/.cache/pip/wheels/b4/1f/b8/66bd9bc3a9d6c6987ff6c4dfeb6f1fe97b5a0e5ed5849c0437
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158155 sha256=c7c7a2d1a11e19a12d424ab6051add5ff6925d5ee03f9144defaad5a27a6983c
#   Stored in directory: /root/.cache/pip/wheels/84/07/f7/12f7370ca47a66030c2edeedcc23dec26ea0ac22dcb4c4a0f3
# Successfully built sqlalchemy databricks-cli prometheus-flask-exporter alembic
# Installing collected packages: querystring-parser, sqlalchemy, cryptography, isodate, msrest, azure-core, azure-storage-blob, websocket-client, docker, databricks-cli, prometheus-flask-exporter, Mako, python-editor, alembic, gunicorn, smmap, gitdb, gitpython, gorilla, mlflow
#   Found existing installation: SQLAlchemy 1.3.20
#     Uninstalling SQLAlchemy-1.3.20:
#       Successfully uninstalled SQLAlchemy-1.3.20
# Successfully installed Mako-1.1.3 alembic-1.4.1 azure-core-1.8.2 azure-storage-blob-12.5.0 cryptography-3.2.1 databricks-cli-0.13.0 docker-4.3.1 gitdb-4.0.5 gitpython-3.1.11 gorilla-0.3.0 gunicorn-20.0.4 isodate-0.6.0 mlflow-1.11.0 msrest-0.6.19 prometheus-flask-exporter-0.18.1 python-editor-1.0.4 querystring-parser-1.2.4 smmap-3.0.4 sqlalchemy-1.3.13 websocket-client-0.57.0

# %%
# %%writefile intents.json
# {"intents": [
#     {"tag": "greeting",
#      "patterns": ["Hi", "Hey", "Is anyone there?", "Hello", "Hay"],
#      "responses": ["Hello", "Hi", "Hi there"]
#     },
#     {"tag": "goodbye",
#      "patterns": ["Bye", "See you later", "Goodbye"],
#      "responses": ["See you later", "Have a nice day", "Bye! Come back again"]
#     },
#     {"tag": "thanks",
#      "patterns": ["Thanks", "Thank you", "That's helpful", "Thanks for the help"],
#      "responses": ["Happy to help!", "Any time!", "My pleasure", "You're most welcome!"]
#     },
#     {"tag": "about",
#      "patterns": ["Who are you?", "What are you?", "Who you are?" ],
#      "responses": ["I.m Joana, your bot assistant", "I'm Joana, an Artificial Intelligent bot"]
#     },
#     {"tag": "name",
#     "patterns": ["what is your name", "what should I call you", "whats your name?"],
#     "responses": ["You can call me Joana.", "I'm Joana!", "Just call me as Joana"]
#     },
#     {"tag": "help",
#     "patterns": ["Could you help me?", "give me a hand please", "Can you help?", "What can you do for me?", "I need a support", "I need a help", "support me please"],
#     "responses": ["Tell me how can assist you", "Tell me your problem to assist you", "Yes Sure, How can I support you"]
#     },
#     {"tag": "createaccount",
#     "patterns": ["I need to create a new account", "how to open a new account", "I want to create an account", "can you create an account for me", "how to open a new account"],
#     "responses": ["You can just easily create a new account from our web site", "Just go to our web site and follow the guidelines to create a new account"]
#     },
#     {"tag": "complaint",
#     "patterns": ["have a complaint", "I want to raise a complaint", "there is a complaint about a service"],
#     "responses": ["Please provide us your complaint in order to assist you", "Please mention your complaint, we will reach you and sorry for any inconvenience caused"]
#     }
# ]
# }
# Out:
# Writing intents.json

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import mlflow

# %% [markdown]
# ###Mlflow config

# %%
#Mlflow settings
MLFLOW_URL='http://mlops.getmytrainer.net:5001'
EXPERIMENT='npl/chatbot'
EPOCHS=500
VERSION=1
LOSS='sparse_categorical_crossentropy'
OPTIMIZER='adam'

#Set tags
tags={}
tags['TYPE']='IMAGE_RECOGNITION'
tags['TRANSFER_LEARNING']='NO'
tags['TFHUB']='NO'

SAVE_PATH='saved_model'
# %mkdir saved_model

#set MLflow server 
mlflow.set_tracking_uri(MLFLOW_URL)
#Set experiment
if mlflow.get_experiment_by_name(EXPERIMENT) != None:
    exp_id = mlflow.set_experiment(EXPERIMENT)
else: 
    exp_id = mlflow.create_experiment(EXPERIMENT)

#Close active runs
if mlflow.active_run():
    mlflow.end_run()
# Out:
# mkdir: cannot create directory ‘saved_model’: File exists

# %% [markdown]
# ### Data Preparation

# %%
with open('intents.json') as file:
    data = json.load(file)
    
training_sentences = []
training_labels = []
labels = []
responses = []

for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
print("training sentences: ", len(training_sentences)) #holds all the training data (which are the sample messages in each intent category)
print("training labels: ", len(training_labels)) #holds all the target labels correspond to each training data
print("labels: ", len(labels))
print("responses: ", len(responses))
# Out:
# training sentences:  33
# training labels:  33
# labels:  8
# responses:  8

# %%
#convert the target labels into a model understandable form
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
#vectorize our text data corpus by using the “Tokenizer” class and it allows us to limit our vocabulary size up to some defined number.
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len) #used to make all the training text sequences into the same size

# %% [markdown]
# ### Model Training

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=LOSS, 
              optimizer=OPTIMIZER, metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 20, 16)            16000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 136
# =================================================================
# Total params: 16,680
# Trainable params: 16,680
# Non-trainable params: 0
# _________________________________________________________________

# %%
with mlflow.start_run(run_id=None, experiment_id=exp_id, run_name=None, nested=False):
  
  history = model.fit(padded_sequences, np.array(training_labels), epochs=EPOCHS)

  hist=history.history

  #mlflow autolog
  #mlflow.tensorflow.autolog()

  #Set tags
  mlflow.set_tags(tags)

  #mlflow logging
  # log parameters
  #mlflow.log_param("hidden_layers", args.hidden_layers)
  #mlflow.log_param("output", args.output)
  mlflow.log_param("epochs", EPOCHS)
  mlflow.log_param("loss_function", LOSS)
  mlflow.log_param("optimizer", OPTIMIZER)

  # log metrics
  for epoch in range(0, EPOCHS):
    mlflow.log_metric("accuracy", hist['accuracy'][epoch])
    mlflow.log_metric("loss",  hist['loss'][epoch])
    #mlflow.log_metric("val_accuracy",  hist['val_accuracy'][epoch])
    #mlflow.log_metric("val_loss",  hist['val_loss'][epoch])
  
  #log model
  #model.save(os.path.join(BASE_DIR, "models", "{}.h5".format(int(t)))) #HDF5 format
  tf.saved_model.save(model, SAVE_PATH) #SavedModel format
  #mlflow.tensorflow.log_model(model, 'model') #TODO fix
  
  # log artifacts (matplotlib images for loss/accuracy)
  #mlflow.log_artifacts(image_dir)

  mlflow.end_run()
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0645 - accuracy: 1.0000
# Epoch 2/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 1.0000
# Epoch 3/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 4/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 1.0000
# Epoch 5/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 6/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 7/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 1.0000
# Epoch 8/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 1.0000
# Epoch 9/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 10/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 11/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 12/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 13/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 14/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 15/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 16/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0590 - accuracy: 1.0000
# Epoch 17/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 18/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 1.0000
# Epoch 19/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 20/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 21/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 22/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 23/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 24/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 25/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 26/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0567 - accuracy: 1.0000
# Epoch 27/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 28/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 29/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 30/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 31/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 32/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 33/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 34/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 35/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 36/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 37/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 38/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 39/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 40/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 41/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 42/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 43/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 44/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 45/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 46/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 47/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 48/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 49/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 50/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 51/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 52/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 53/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 54/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 55/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 56/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 57/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 58/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 59/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 60/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 61/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 62/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 63/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 64/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 65/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 66/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 67/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 68/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 69/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 70/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 71/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 72/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 73/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 74/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 75/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 76/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 77/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 78/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 79/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 80/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 81/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 82/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 83/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 84/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 85/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 86/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 87/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 88/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 89/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 90/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 91/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 92/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 93/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 94/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 95/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 96/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 97/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 98/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 99/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 100/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 101/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 102/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 103/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 104/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 105/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 106/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 107/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 108/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 109/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 110/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 111/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 112/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 1.0000
# Epoch 113/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 114/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 115/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 116/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 117/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 118/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 119/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 120/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 121/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 122/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 123/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 124/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 125/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 126/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 127/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 128/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 129/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 130/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 131/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 132/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 133/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 134/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 135/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 136/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 137/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 138/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 139/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 140/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 141/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 142/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 143/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 144/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 145/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 146/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 147/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 148/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 149/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 150/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 151/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 152/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 153/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 154/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 155/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 156/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 157/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 158/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 159/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 160/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 161/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 162/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 163/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 164/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 165/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 166/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 167/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 168/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 169/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 170/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 171/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 172/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 173/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 174/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 175/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 176/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 177/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 178/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 179/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 180/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 181/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 182/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 183/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 184/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 185/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 186/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 187/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 188/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 189/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 190/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 191/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 192/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 193/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 194/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 195/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 196/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 197/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 198/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 199/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 200/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 201/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 202/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 203/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 204/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 205/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 206/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 207/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 208/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 209/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 210/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 211/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 212/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 213/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 214/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 215/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 216/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 217/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 218/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 219/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 220/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 221/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 222/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 223/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 224/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 225/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 226/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 227/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 228/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 229/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 230/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 231/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 232/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 233/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 234/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 235/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 236/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 237/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 238/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 239/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 240/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 241/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 242/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 243/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 244/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 245/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 246/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 247/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 248/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 249/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 250/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 251/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 252/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 253/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 254/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 255/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 256/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 257/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 258/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 259/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 260/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 261/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 262/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 263/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 264/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 265/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 266/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 267/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 268/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 269/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 270/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 271/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 272/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 273/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 274/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 275/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 276/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 277/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 278/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 279/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 280/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 281/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 282/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 283/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 284/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 285/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 286/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 287/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 288/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 289/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 290/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 291/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 292/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 293/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 294/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 295/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 296/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 297/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 298/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 299/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 300/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 301/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 302/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 303/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 304/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 305/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 306/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 307/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 308/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 309/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 310/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 311/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 312/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 313/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 314/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 315/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 316/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 317/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 318/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 319/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 320/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 321/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 322/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 323/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 324/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 325/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 326/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 327/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 328/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 329/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 330/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 331/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 332/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 333/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 334/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 335/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 336/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 337/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 338/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 339/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 340/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 341/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 342/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 343/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 344/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 345/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 346/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 347/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 348/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 349/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 350/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 351/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 352/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 353/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 354/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 355/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 356/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 357/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 358/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 359/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 360/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 361/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 362/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 363/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 364/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 365/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 366/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 367/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 368/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 369/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 370/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 371/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 372/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 373/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 374/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 375/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 376/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 377/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 378/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 379/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 380/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 381/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 382/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 383/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 384/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 385/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 386/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 387/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 388/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 389/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 390/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 391/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 392/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 393/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 394/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 395/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 396/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 397/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 398/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 399/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 400/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 401/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 402/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 403/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 404/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 405/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 406/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 407/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 408/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 409/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 410/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 411/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 412/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 413/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 414/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 415/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 416/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 417/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 418/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 419/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 420/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 421/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 422/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 423/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 424/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 425/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 426/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 427/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 428/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 429/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 430/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 431/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 432/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 433/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 434/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 435/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 436/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 437/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 438/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 439/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 440/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 441/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 442/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 443/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 444/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 445/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 446/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 447/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 448/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 449/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 450/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 451/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 452/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 453/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 454/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 455/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 456/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 457/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 458/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 459/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 460/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 461/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 462/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 463/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 464/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 465/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 466/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 467/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 468/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 469/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 470/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 471/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 472/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 473/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 474/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 475/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 476/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 477/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 478/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 479/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 480/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 481/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 482/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 483/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 484/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 485/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 486/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 487/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 488/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 489/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 490/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 491/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 492/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 493/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 494/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 495/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 496/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 497/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 498/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 499/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 500/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0126 - accuracy: 1.0000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/assets

# %%
import pickle

# %mkdir -p utils

# to save the fitted tokenizer
with open('utils/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('utils/label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intents.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('saved_model')

    # load tokenizer object
    with open('utils/tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('utils/label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        for i in data['intents']:
            if i['tag'] == tag:
                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))

        # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User: Ros
# ChatBot: Have a nice day
# User: hello
# ChatBot: Hi
# User: ciao
# ChatBot: Bye! Come back again
# User: greetings
# ChatBot: See you later
# User: what's your name?
# ChatBot: Just call me as Joana
# User: Joana?
# ChatBot: Bye! Come back again
# User: who are you?
# ChatBot: I.m Joana, your bot assistant
# User: what's the meaning of the life?
# ChatBot: See you later
# User:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-78e427833232> in <module>()
#      47
#      48 print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
# ---> 49 chat()
#
# <ipython-input-28-78e427833232> in chat()
#      32     while True:
#      33         print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
# ---> 34         inp = input()
#      35         if inp.lower() == "quit":
#      36             break
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
