# %%
#Thanks to: https://www.curiousily.com/posts/object-detection-on-custom-dataset-with-tensorflow-2-and-keras-using-python/

# %%
#MLFlow tutorial https://databricks.com/blog/2018/09/21/how-to-use-mlflow-to-reproduce-results-and-retrain-saved-keras-ml-models.html

# %%
from mlflow import log_metric, log_param, log_artifact

# %%
# !pip3 install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting sklearn
#   Downloading https://www.piwheels.org/simple/sklearn/sklearn-0.0-py2.py3-none-any.whl
# Collecting scikit-learn (from sklearn)
#   Downloading https://www.piwheels.org/simple/scikit-learn/scikit_learn-0.22.1-cp37-cp37m-linux_armv7l.whl (19.4MB)
#     100% |████████████████████████████████| 19.4MB 13kB/s eta 0:00:01   37% |████████████                    | 7.3MB 2.2MB/s eta 0:00:06    54% |█████████████████▍              | 10.6MB 3.3MB/s eta 0:00:03    95% |██████████████████████████████▍ | 18.4MB 3.4MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.17.0 in /usr/lib/python3/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/lib/python3/dist-packages (from scikit-learn->sklearn) (1.16.2)
# Collecting joblib>=0.11 (from scikit-learn->sklearn)
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
#     100% |████████████████████████████████| 296kB 410kB/s ta 0:00:01
# Installing collected packages: joblib, scikit-learn, sklearn
# Successfully installed joblib-0.14.1 scikit-learn-0.22.1 sklearn-0.0

# %%
import pandas as pd
import urllib.request
from PIL import Image
from sklearn.model_selection import train_test_split

# %%
# !pip3 install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting gdown
#   Downloading https://www.piwheels.org/simple/gdown/gdown-3.9.1-py3-none-any.whl
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from gdown) (1.12.0)
# Collecting tqdm (from gdown)
#   Downloading https://files.pythonhosted.org/packages/72/c9/7fc20feac72e79032a7c8138fd0d395dc6d8812b5b9edf53c3afd0b31017/tqdm-4.41.1-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 726kB/s ta 0:00:01
# Requirement already satisfied: requests[socks] in /usr/lib/python3/dist-packages (from gdown) (2.21.0)
# Collecting filelock (from gdown)
#   Downloading https://files.pythonhosted.org/packages/93/83/71a2ee6158bb9f39a90c0dea1637f81d5eef866e188e1971a1b1ab01a35a/filelock-3.0.12-py3-none-any.whl
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading https://files.pythonhosted.org/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl
# Installing collected packages: tqdm, filelock, gdown, PySocks
# Successfully installed PySocks-1.7.1 filelock-3.0.12 gdown-3.9.1 tqdm-4.41.1

# %%
# !gdown --id 1mTtB8GTWs74Yeqm0KMExGJZh1eDbzUlT --output indian_number_plates.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mTtB8GTWs74Yeqm0KMExGJZh1eDbzUlT
# To: /home/pi/Codice/notebooks/indian_number_plates.json
# 100%|██████████████████████████████████████| 92.5k/92.5k [00:00<00:00, 3.10MB/s]

# %%
plates_df = pd.read_json('indian_number_plates.json', lines=True)

# %%
import os
os.makedirs("number_plates", exist_ok=True)

# %%
dataset = dict()
dataset["image_name"] = list()
dataset["top_x"] = list()
dataset["top_y"] = list()
dataset["bottom_x"] = list()
dataset["bottom_y"] = list()
dataset["class_name"] = list()

# %%
#download train and convert the data into the format that Keras Retina understands
counter = 0
for index, row in plates_df.iterrows():
    img = urllib.request.urlopen(row["content"])
    img = Image.open(img)
    img = img.convert('RGB')
    img.save(f'number_plates/licensed_car_{counter}.jpeg', "JPEG")

    dataset["image_name"].append(
      f'number_plates/licensed_car_{counter}.jpeg'
    )

    data = row["annotation"]

    width = data[0]["imageWidth"]
    height = data[0]["imageHeight"]

    dataset["top_x"].append(int(round(data[0]["points"][0]["x"] * width)))
    dataset["top_y"].append(int(round(data[0]["points"][0]["y"] * height)))
    dataset["bottom_x"].append(int(round(data[0]["points"][1]["x"] * width)))
    dataset["bottom_y"].append(int(round(data[0]["points"][1]["y"] * height)))
    
    dataset["class_name"].append("license_plate")

    counter += 1

# %%
print("Downloaded {} car images.".format(counter))
# Out:
# Downloaded 237 car images.

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                               image_name  top_x  top_y  bottom_x  bottom_y  \
# 0      number_plates/licensed_car_0.jpeg    582    274       700       321
# 1      number_plates/licensed_car_1.jpeg     80    382       288       449
# 2      number_plates/licensed_car_2.jpeg     41    219       115       260
# 3      number_plates/licensed_car_3.jpeg    217    313       359       359
# 4      number_plates/licensed_car_4.jpeg    209    220       866       554
# 5      number_plates/licensed_car_5.jpeg    106    280       261       335
# 6      number_plates/licensed_car_6.jpeg    227    241       444       315
# 7      number_plates/licensed_car_7.jpeg    267    248       396       320
# 8      number_plates/licensed_car_8.jpeg    644    508       893       578
# 9      number_plates/licensed_car_9.jpeg    674    365       958       572
# 10    number_plates/licensed_car_10.jpeg    200    138       422       219
# 11    number_plates/licensed_car_11.jpeg    348    378       499       437
# 12    number_plates/licensed_car_12.jpeg    215    186       437       239
# 13    number_plates/licensed_car_13.jpeg     99    222       244       336
# 14    number_plates/licensed_car_14.jpeg    151    103       360       186
# 15    number_plates/licensed_car_15.jpeg    274    344       517       431
# 16    number_plates/licensed_car_16.jpeg    292    258       489       320
# 17    number_plates/licensed_car_17.jpeg     60    216       187       280
# 18    number_plates/licensed_car_18.jpeg    334    191       433       234
# 19    number_plates/licensed_car_19.jpeg    262    190       742       393
# 20    number_plates/licensed_car_20.jpeg    148    178       355       275
# 21    number_plates/licensed_car_21.jpeg    273      3       511        66
# 22    number_plates/licensed_car_22.jpeg    250    506       487       584
# 23    number_plates/licensed_car_23.jpeg    288    423       572       496
# 24    number_plates/licensed_car_24.jpeg    162    198       431       278
# 25    number_plates/licensed_car_25.jpeg    283    178       433       221
# 26    number_plates/licensed_car_26.jpeg    183    219       457       320
# 27    number_plates/licensed_car_27.jpeg     49    185       247       294
# 28    number_plates/licensed_car_28.jpeg    297    123      2422       615
# 29    number_plates/licensed_car_29.jpeg    121     43      1496       338
# ..                                   ...    ...    ...       ...       ...
# 207  number_plates/licensed_car_207.jpeg    138     66       451       155
# 208  number_plates/licensed_car_208.jpeg    154    196       377       259
# 209  number_plates/licensed_car_209.jpeg     56    221       265       289
# 210  number_plates/licensed_car_210.jpeg    131    104       405       226
# 211  number_plates/licensed_car_211.jpeg    157     89       382       160
# 212  number_plates/licensed_car_212.jpeg    144    113       348       199
# 213  number_plates/licensed_car_213.jpeg    124    110       400       207
# 214  number_plates/licensed_car_214.jpeg    143    244       339       321
# 215  number_plates/licensed_car_215.jpeg    184    305       389       370
# 216  number_plates/licensed_car_216.jpeg    237    102       387       162
# 217  number_plates/licensed_car_217.jpeg    111    117       391       211
# 218  number_plates/licensed_car_218.jpeg    180    115       380       188
# 219  number_plates/licensed_car_219.jpeg    140    155       328       212
# 220  number_plates/licensed_car_220.jpeg     55    191       194       238
# 221  number_plates/licensed_car_221.jpeg     93    332       298       406
# 222  number_plates/licensed_car_222.jpeg    141    221       351       273
# 223  number_plates/licensed_car_223.jpeg    136    196       348       278
# 224  number_plates/licensed_car_224.jpeg     24     36       187       104
# 225  number_plates/licensed_car_225.jpeg    143    206       402       273
# 226  number_plates/licensed_car_226.jpeg    186     98       363       155
# 227  number_plates/licensed_car_227.jpeg    100    143       218       194
# 228  number_plates/licensed_car_228.jpeg    109    106       235       162
# 229  number_plates/licensed_car_229.jpeg    102    134       262       200
# 230  number_plates/licensed_car_230.jpeg    140    149       324       220
# 231  number_plates/licensed_car_231.jpeg     13    117       147       186
# 232  number_plates/licensed_car_232.jpeg    172    223       353       285
# 233  number_plates/licensed_car_233.jpeg    184    151       308       206
# 234  number_plates/licensed_car_234.jpeg    167    202       314       255
# 235  number_plates/licensed_car_235.jpeg    173    199       259       238
# 236  number_plates/licensed_car_236.jpeg     16     19       367       126
#
#         class_name
# 0    license_plate
# 1    license_plate
# 2    license_plate
# 3    license_plate
# 4    license_plate
# 5    license_plate
# 6    license_plate
# 7    license_plate
# 8    license_plate
# 9    license_plate
# 10   license_plate
# 11   license_plate
# 12   license_plate
# 13   license_plate
# 14   license_plate
# 15   license_plate
# 16   license_plate
# 17   license_plate
# 18   license_plate
# 19   license_plate
# 20   license_plate
# 21   license_plate
# 22   license_plate
# 23   license_plate
# 24   license_plate
# 25   license_plate
# 26   license_plate
# 27   license_plate
# 28   license_plate
# 29   license_plate
# ..             ...
# 207  license_plate
# 208  license_plate
# 209  license_plate
# 210  license_plate
# 211  license_plate
# 212  license_plate
# 213  license_plate
# 214  license_plate
# 215  license_plate
# 216  license_plate
# 217  license_plate
# 218  license_plate
# 219  license_plate
# 220  license_plate
# 221  license_plate
# 222  license_plate
# 223  license_plate
# 224  license_plate
# 225  license_plate
# 226  license_plate
# 227  license_plate
# 228  license_plate
# 229  license_plate
# 230  license_plate
# 231  license_plate
# 232  license_plate
# 233  license_plate
# 234  license_plate
# 235  license_plate
# 236  license_plate
#
# [237 rows x 6 columns]

# %%
RANDOM_SEED = 42
train_df, test_df = train_test_split(df,test_size=0.2,random_state=RANDOM_SEED)

# %%
train_df
# Out:
#                               image_name  top_x  top_y  bottom_x  bottom_y  \
# 183  number_plates/licensed_car_183.jpeg    169    260       358       298
# 201  number_plates/licensed_car_201.jpeg    251    187       375       234
# 230  number_plates/licensed_car_230.jpeg    140    149       324       220
# 95    number_plates/licensed_car_95.jpeg    302    420       671       534
# 190  number_plates/licensed_car_190.jpeg    115     86       227       117
# ..                                   ...    ...    ...       ...       ...
# 106  number_plates/licensed_car_106.jpeg    230    187       327       249
# 14    number_plates/licensed_car_14.jpeg    151    103       360       186
# 92    number_plates/licensed_car_92.jpeg    151    354       303       426
# 179  number_plates/licensed_car_179.jpeg    389    450       600       509
# 102  number_plates/licensed_car_102.jpeg    128     74       361       202
#
#         class_name
# 183  license_plate
# 201  license_plate
# 230  license_plate
# 95   license_plate
# 190  license_plate
# ..             ...
# 106  license_plate
# 14   license_plate
# 92   license_plate
# 179  license_plate
# 102  license_plate
#
# [189 rows x 6 columns]

# %%
ANNOTATIONS_FILE = 'annotations.csv'
CLASSES_FILE = 'classes.csv'
#Pandas to write the annotations file, excluding the index and header:
train_df.to_csv(ANNOTATIONS_FILE, index=False, header=None)

# %%
#regular old file writer for the classes:

classes = set(['license_plate'])

with open(CLASSES_FILE, 'w') as f:
  for i, line in enumerate(sorted(classes)):
    f.write('{},{}\n'.format(line,i))

# %%
os.makedirs("snapshots", exist_ok=True)

# %%
#downloading generic pre-trained-model trained on COCO dataset
# !gdown --id 1wPgOBoSks6bTIs9RzNvZf6HWROkciS8R --output snapshots\resnet50_csv_10.h5

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git

# %%
#RESUME FROM HERE!
#Getting Resinanet Keras implementation
PRETRAINED_MODEL = './snapshots/_pretrained_model.h5'
URL_MODEL = 'https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_coco_best_v2.1.0.h5'
urllib.request.urlretrieve(URL_MODEL, PRETRAINED_MODEL)

print('Downloaded pretrained model to ' + PRETRAINED_MODEL)
# Out:
# Downloaded pretrained model to ./snapshots/_pretrained_model.h5

# %%
# !pip3 install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting opencv-python
#   Downloading https://www.piwheels.org/simple/opencv-python/opencv_python-4.1.1.26-cp37-cp37m-linux_armv7l.whl (10.0MB)
#     100% |████████████████████████████████| 10.0MB 22kB/s eta 0:00:01   14% |████▌                           | 1.4MB 3.2MB/s eta 0:00:03
# Requirement already satisfied: numpy>=1.16.2 in /usr/lib/python3/dist-packages (from opencv-python) (1.16.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.1.1.26

# %%
# !pip3 install keras-retinanet
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting keras-retinanet
#   Downloading https://www.piwheels.org/simple/keras-retinanet/keras_retinanet-0.5.1-cp37-cp37m-linux_armv7l.whl (164kB)
#     100% |████████████████████████████████| 174kB 485kB/s ta 0:00:01
# Collecting cython (from keras-retinanet)
#   Downloading https://www.piwheels.org/simple/cython/Cython-0.29.14-cp37-cp37m-linux_armv7l.whl (4.8MB)
#     100% |████████████████████████████████| 4.8MB 35kB/s eta 0:00:01
# Requirement already satisfied: opencv-python in /home/pi/.local/lib/python3.7/site-packages (from keras-retinanet) (4.1.1.26)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from keras-retinanet) (5.4.1)
# Collecting keras-resnet (from keras-retinanet)
#   Downloading https://www.piwheels.org/simple/keras-resnet/keras_resnet-0.2.0-py2.py3-none-any.whl
# Collecting progressbar2 (from keras-retinanet)
#   Downloading https://files.pythonhosted.org/packages/16/68/adc395e0a3c86571081c8a2e2daaa5b58270f6854276a089a0e9b5fa2c33/progressbar2-3.47.0-py2.py3-none-any.whl
# Requirement already satisfied: keras in /home/pi/.local/lib/python3.7/site-packages (from keras-retinanet) (2.3.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from keras-retinanet) (1.12.0)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from keras-retinanet) (1.1.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/lib/python3/dist-packages (from opencv-python->keras-retinanet) (1.16.2)
# Collecting python-utils>=2.3.0 (from progressbar2->keras-retinanet)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/pi/.local/lib/python3.7/site-packages (from keras->keras-retinanet) (1.1.0)
# Requirement already satisfied: pyyaml in /home/pi/.local/lib/python3.7/site-packages (from keras->keras-retinanet) (5.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/pi/.local/lib/python3.7/site-packages (from keras->keras-retinanet) (1.0.8)
# Requirement already satisfied: h5py in /home/pi/.local/lib/python3.7/site-packages (from keras->keras-retinanet) (2.10.0)
# Installing collected packages: cython, keras-resnet, python-utils, progressbar2, keras-retinanet
# Successfully installed cython-0.29.14 keras-resnet-0.2.0 keras-retinanet-0.5.1 progressbar2-3.47.0 python-utils-2.3.0

# %%
# !sudo apt-get install -y libatlas-base-dev
# !sudo apt-get install -y libjasper-dev
# !sudo apt-get install -y libqtgui4
# !sudo apt-get install -y python3-pyqt5
#!sudo apt-get install -y libgtk2.0-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libatlas-base-dev is already the newest version (3.10.3-8+rpi1).
# 0 upgraded, 0 newly installed, 0 to remove and 160 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libjasper1
# Suggested packages:
#   libjasper-runtime
# The following NEW packages will be installed:
#   libjasper-dev libjasper1
# 0 upgraded, 2 newly installed, 0 to remove and 160 not upgraded.
# Need to get 611 kB of archives.
# After this operation, 1,207 kB of additional disk space will be used.
# Get:1 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libjasper1 armhf 1.900.1-debian1-2.4+deb8u1 [110 kB]
# Get:2 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libjasper-dev armhf 1.900.1-debian1-2.4+deb8u1 [501 kB]
# Fetched 611 kB in 1s (474 kB/s)
# Selecting previously unselected package libjasper1:armhf.
# (Reading database ... 99261 files and directories currently installed.)
# Preparing to unpack .../libjasper1_1.900.1-debian1-2.4+deb8u1_armhf.deb ...
# Unpacking libjasper1:armhf (1.900.1-debian1-2.4+deb8u1) ...
# Selecting previously unselected package libjasper-dev.
# Preparing to unpack .../libjasper-dev_1.900.1-debian1-2.4+deb8u1_armhf.deb ...
# Unpacking libjasper-dev (1.900.1-debian1-2.4+deb8u1) ...
# Setting up libjasper1:armhf (1.900.1-debian1-2.4+deb8u1) ...
# Setting up libjasper-dev (1.900.1-debian1-2.4+deb8u1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libaudio2 libjpeg8 libmng1 libqt4-dbus libqt4-xml libqtcore4 libqtdbus4
#   qdbus qt-at-spi qtchooser qtcore4-l10n
# Suggested packages:
#   nas libicu57 qt4-qtconfig
# The following NEW packages will be installed:
#   libaudio2 libjpeg8 libmng1 libqt4-dbus libqt4-xml libqtcore4 libqtdbus4
#   libqtgui4 qdbus qt-at-spi qtchooser qtcore4-l10n
# 0 upgraded, 12 newly installed, 0 to remove and 160 not upgraded.
# Need to get 6,294 kB of archives.
# After this operation, 22.2 MB of additional disk space will be used.
# Get:1 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libjpeg8 armhf 8d1-2 [108 kB]
# Get:2 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libmng1 armhf 1.0.10+dfsg-3.1 [164 kB]
# Get:3 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libaudio2 armhf 1.9.4-6 [72.7 kB]
# Get:12 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf qt-at-spi armhf 0.4.0-9 [48.3 kB]
# Get:4 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf qtcore4-l10n all 4:4.8.7+dfsg-18+rpi1 [662 kB]
# Get:5 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqtcore4 armhf 4:4.8.7+dfsg-18+rpi1 [1,361 kB]
# Get:6 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqt4-xml armhf 4:4.8.7+dfsg-18+rpi1 [127 kB]
# Get:7 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqtdbus4 armhf 4:4.8.7+dfsg-18+rpi1 [194 kB]
# Get:8 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf qtchooser armhf 66-2 [23.1 kB]
# Get:9 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf qdbus armhf 4:4.8.7+dfsg-18+rpi1 [73.0 kB]
# Get:10 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqt4-dbus armhf 4:4.8.7+dfsg-18+rpi1 [54.0 kB]
# Get:11 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqtgui4 armhf 4:4.8.7+dfsg-18+rpi1 [3,408 kB]
# Fetched 6,294 kB in 6s (1,015 kB/s)
# Selecting previously unselected package libjpeg8:armhf.
# (Reading database ... 99294 files and directories currently installed.)
# Preparing to unpack .../00-libjpeg8_8d1-2_armhf.deb ...
# Unpacking libjpeg8:armhf (8d1-2) ...
# Selecting previously unselected package libmng1:armhf.
# Preparing to unpack .../01-libmng1_1.0.10+dfsg-3.1_armhf.deb ...
# Unpacking libmng1:armhf (1.0.10+dfsg-3.1) ...
# Selecting previously unselected package libaudio2:armhf.
# Preparing to unpack .../02-libaudio2_1.9.4-6_armhf.deb ...
# Unpacking libaudio2:armhf (1.9.4-6) ...
# Selecting previously unselected package qtcore4-l10n.
# Preparing to unpack .../03-qtcore4-l10n_4%3a4.8.7+dfsg-18+rpi1_all.deb ...
# Unpacking qtcore4-l10n (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package libqtcore4:armhf.
# Preparing to unpack .../04-libqtcore4_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking libqtcore4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package libqt4-xml:armhf.
# Preparing to unpack .../05-libqt4-xml_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking libqt4-xml:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package libqtdbus4:armhf.
# Preparing to unpack .../06-libqtdbus4_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking libqtdbus4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package qtchooser.
# Preparing to unpack .../07-qtchooser_66-2_armhf.deb ...
# Unpacking qtchooser (66-2) ...
# Selecting previously unselected package qdbus.
# Preparing to unpack .../08-qdbus_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking qdbus (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package libqt4-dbus:armhf.
# Preparing to unpack .../09-libqt4-dbus_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking libqt4-dbus:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package libqtgui4:armhf.
# Preparing to unpack .../10-libqtgui4_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# Unpacking libqtgui4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Selecting previously unselected package qt-at-spi:armhf.
# Preparing to unpack .../11-qt-at-spi_0.4.0-9_armhf.deb ...
# Unpacking qt-at-spi:armhf (0.4.0-9) ...
# Setting up libjpeg8:armhf (8d1-2) ...
# Setting up libmng1:armhf (1.0.10+dfsg-3.1) ...
# Setting up libaudio2:armhf (1.9.4-6) ...
# Setting up qtchooser (66-2) ...
# Setting up qtcore4-l10n (4:4.8.7+dfsg-18+rpi1) ...
# Setting up libqtcore4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Setting up libqtgui4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Setting up libqt4-xml:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Setting up libqtdbus4:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Setting up qdbus (4:4.8.7+dfsg-18+rpi1) ...
# Setting up libqt4-dbus:armhf (4:4.8.7+dfsg-18+rpi1) ...
# Setting up qt-at-spi:armhf (0.4.0-9) ...
# Processing triggers for man-db (2.8.5-2) ...
# Processing triggers for libc-bin (2.28-10+rpi1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libqt5designer5 libqt5help5 libqt5test5 python3-sip
# Suggested packages:
#   python3-pyqt5-dbg
# The following NEW packages will be installed:
#   libqt5designer5 libqt5help5 libqt5test5 python3-pyqt5 python3-sip
# 0 upgraded, 5 newly installed, 0 to remove and 160 not upgraded.
# Need to get 4,799 kB of archives.
# After this operation, 19.5 MB of additional disk space will be used.
# Get:1 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libqt5designer5 armhf 5.11.3-4 [2,632 kB]
# Get:2 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf libqt5help5 armhf 5.11.3-4 [124 kB]
# Get:5 http://raspbian.mirror.garr.it/mirrors/raspbian/raspbian buster/main armhf python3-pyqt5 armhf 5.11.3+dfsg-1+rpi1+b3 [1,752 kB]
# Get:3 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqt5test5 armhf 5.11.3+dfsg1-1+rpi1 [132 kB]
# Get:4 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf python3-sip armhf 4.19.14+dfsg-2 [158 kB]
# Fetched 4,799 kB in 13s (369 kB/s)
# Selecting previously unselected package libqt5designer5:armhf.
# (Reading database ... 99497 files and directories currently installed.)
# Preparing to unpack .../libqt5designer5_5.11.3-4_armhf.deb ...
# Unpacking libqt5designer5:armhf (5.11.3-4) ...
# Selecting previously unselected package libqt5help5:armhf.
# Preparing to unpack .../libqt5help5_5.11.3-4_armhf.deb ...
# Unpacking libqt5help5:armhf (5.11.3-4) ...
# Selecting previously unselected package libqt5test5:armhf.
# Preparing to unpack .../libqt5test5_5.11.3+dfsg1-1+rpi1_armhf.deb ...
# Unpacking libqt5test5:armhf (5.11.3+dfsg1-1+rpi1) ...
# Selecting previously unselected package python3-sip.
# Preparing to unpack .../python3-sip_4.19.14+dfsg-2_armhf.deb ...
# Unpacking python3-sip (4.19.14+dfsg-2) ...
# Selecting previously unselected package python3-pyqt5.
# Preparing to unpack .../python3-pyqt5_5.11.3+dfsg-1+rpi1+b3_armhf.deb ...
# Unpacking python3-pyqt5 (5.11.3+dfsg-1+rpi1+b3) ...
# Setting up libqt5designer5:armhf (5.11.3-4) ...
# Setting up libqt5help5:armhf (5.11.3-4) ...
# Setting up libqt5test5:armhf (5.11.3+dfsg1-1+rpi1) ...
# Setting up python3-sip (4.19.14+dfsg-2) ...
# Setting up python3-pyqt5 (5.11.3+dfsg-1+rpi1+b3) ...
# Processing triggers for libc-bin (2.28-10+rpi1) ...

# %%
# !sudo apt install -y libqt4-test
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libqt4-test
# 0 upgraded, 1 newly installed, 0 to remove and 156 not upgraded.
# Need to get 97.8 kB of archives.
# After this operation, 250 kB of additional disk space will be used.
# Get:1 http://ftp.arnes.si/mirrors/raspbian/raspbian buster/main armhf libqt4-test armhf 4:4.8.7+dfsg-18+rpi1 [97.8 kB]33m
# Fetched 97.8 kB in 8s (12.9 kB/s)
#
# 78Selecting previously unselected package libqt4-test:armhf.
# (Reading database ... 103318 files and directories currently installed.)
# Preparing to unpack .../libqt4-test_4%3a4.8.7+dfsg-18+rpi1_armhf.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [ 20%] [###########...............................................] 8Unpacking libqt4-test:armhf (4:4.8.7+dfsg-18+rpi1) ...
# 7Progress: [ 40%] [#######################...................................] 8Setting up libqt4-test:armhf (4:4.8.7+dfsg-18+rpi1) ...
# 7Progress: [ 60%] [##################################........................] 87Progress: [ 80%] [##############################################............] 8Processing triggers for libc-bin (2.28-10+rpi1) ...
#
# 78

# %%
#training model
# !python3.7 ~/.local/lib/python3.7/site-packages/keras_retinanet/bin/train.py \
 --freeze-backbone \
 --random-transform \
 --weights {PRETRAINED_MODEL} \
 --batch-size 8 \
 --steps 500 \
 --epochs 10 \
 csv annotations.csv classes.csv
# Out:
# Using TensorFlow backend.
# 2020-01-13 14:24:14.666601: E tensorflow/core/platform/hadoop/hadoop_file_system.cc:132] HadoopFileSystem load error: libhdfs.so: cannot open shared object file: No such file or directory
# Traceback (most recent call last):
#   File "/home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/train.py", line 39, in <module>
#     from ..callbacks.eval import Evaluate
#   File "/home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/../../keras_retinanet/callbacks/eval.py", line 18, in <module>
#     from ..utils.eval import evaluate
#   File "/home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/../../keras_retinanet/utils/eval.py", line 18, in <module>
#     from .visualization import draw_detections, draw_annotations
#   File "/home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/../../keras_retinanet/utils/visualization.py", line 17, in <module>
#     import cv2
#   File "/home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/../../cv2/__init__.py", line 3, in <module>
#     from .cv2 import *
# ImportError: /home/pi/.local/lib/python3.7/site-packages/keras_retinanet/bin/../../cv2/cv2.cpython-37m-arm-linux-gnueabihf.so: undefined symbol: __atomic_fetch_add_8

# %%
#loading the model 

model_path = os.path.join('snapshots', sorted(os.listdir('snapshots'), reverse=True)[0])

model = models.load_model(model_path, backbone_name='resnet50')
model = models.convert_model(model)

# %%
#convert the classes into a format that will be useful later:
labels_to_names = pd.read_csv(
  CLASSES_FILE,
  header=None
).T.loc[0].to_dict()

# %%
#using model:
def predict(image):
  image = preprocess_image(image.copy())
  image, scale = resize_image(image)

  boxes, scores, labels = model.predict_on_batch(
    np.expand_dims(image, axis=0)
  )

  boxes /= scale

  return boxes, scores, labels
